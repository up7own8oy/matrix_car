# %%
cd "/content/drive/My Drive/Colab Notebooks/DataWorkshop/MatrixTransform2/matrix_car/"
# Out:
# /content/drive/My Drive/Colab Notebooks/DataWorkshop/MatrixTransform2/matrix_car

# %%
GITHUB_TOKEN = '88aec5f66e313cb4b3b2239c3cb62c225aaedd81'

GITHUB_URL = 'https://{}@github.com/up7own8oy/matrix_car.git'.format(GITHUB_TOKEN)

# %%
# !git clone $GITHUB_URL
# Out:
# Cloning into 'matrix_car'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 12 (delta 2), reused 5 (delta 1), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
# !git config --global user.email "up7own8oy@gmail.com"
# !git config --global user.name "Up Town Boy"

# %%
# !git add 03_SimpleModel.ipynb
# !git commit -m "add simple_model"
# Out:
# fatal: pathspec '03_SimpleModel.ipynb' did not match any files
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Untracked files:
# 	matrix_car/
#
# nothing added to commit but untracked files present

# %%
# !git push -u origin master

# %%
# !pip install --upgrade tables
# !pip install eli5
# Out:
# ...
#      |████████████████████████████████| 4.3MB 2.9MB/s
# ...
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# ...
#      |████████████████████████████████| 112kB 2.8MB/s
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import cross_val_score

import eli5
from eli5.sklearn import PermutationImportance
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# ...

# %% [markdown]
# #Wczytywanie Danych

# %%
cd '/content/drive/My Drive/Colab Notebooks/DataWorkshop/MatrixTransform2/matrix_car/'
# Out:
# /content/drive/My Drive/Colab Notebooks/DataWorkshop/MatrixTransform2/matrix_car

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/DataWorkshop/MatrixTransform2/matrix_car

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %%
df.columns
# Out:
# Index(['breadcrumb', 'created_at', 'price_currency', 'price_details',
#        'price_value', 'seller_address', 'seller_name', 'seller_type',
#        'feature_czujniki-parkowania-przednie',
#        'feature_poduszka-powietrzna-chroniąca-kolana',
#        ...
#        'param_pearl', 'param_stan', 'param_wersja', 'param_emisja-co2',
#        'param_body-type', 'param_matowy', 'param_bezwypadkowy',
#        'param_akryl-(niemetalizowany)', 'param_monthly-payment-value',
#        'car_id'],
#       dtype='object', length=155)

# %% [markdown]
# ## Dummy Model

# %%
df.select_dtypes(np.number).columns
# Out:
# Index(['price_value', 'car_id'], dtype='object')

# %%
feats = ['car_id']
X = df[ feats ].values
y = df ['price_value' ]


#Crate Model
model = DummyRegressor()
model.fit(X, y)
y_pred = model.predict(X)

mae(y, y_pred)
# Out:
# 39465.934630440985

# %%
[x for x in df.columns if 'price' in x]
# Out:
# ['price_currency', 'price_details', 'price_value']

# %%
df['price_currency'].value_counts()

# %%
df = df [ df ['price_currency'] != 'EUR' ]
df.shape
# Out:
# (106290, 155)

# %%
df['price_currency'].value_counts()
# Out:
# PLN    106290
# Name: price_currency, dtype: int64

# %% [markdown]
# ## Features - przewidywanie cech

# %%
SUFFIX_CAT = '__cat'
for feat in df.columns:
  if isinstance(df[feat][0], list):continue

  factorized_values = df[feat].factorize()[0]
  if SUFFIX_CAT in feat: 
    df[feat] = factorized_values
  else:
    df[feat + SUFFIX_CAT] = factorized_values

# %%
cat_feats = [x for x in df.columns if SUFFIX_CAT in x]
cat_feats = [x for x in cat_feats if 'price' not in x]
len(cat_feats)
# Out:
# 151

# %%
X = df[cat_feats].values
y = df['price_value'].values

model = DecisionTreeRegressor(max_depth=5)
scores = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')
np.mean(scores)
# Out:
# -19566.588937368328

# %%
m = DecisionTreeRegressor(max_depth=5)
m.fit(X, y)

imp = PermutationImportance(m, random_state=0).fit(X, y)
eli5.show_weights(imp, feature_names=cat_feats )
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2533
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_napęd__cat
#             </td>
# ...
